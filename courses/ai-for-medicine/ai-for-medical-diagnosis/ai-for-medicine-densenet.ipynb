# %% [markdown]
# # AI for Medicine — DenseNet

# %% [markdown]
# Densenet is a convolutional network where each layer is connected to all other layers that are deeper in the network
# - The first layer is connected to the 2nd, 3rd, 4th etc.
# - The second layer is connected to the 3rd, 4th, 5th etc.
#
# For a detailed explanation of Densenet, check out the source of the image above, a paper by Gao Huang et al. 2018 called [Densely Connected Convolutional Networks](https://arxiv.org/pdf/1608.06993.pdf).
#
# The cells below are set up to provide an exploration of the Keras densenet implementation that you'll be using in the assignment. Run these cells to gain some insight into the network architecture.

# %%
import torch
import torch.nn as nn
from torchvision import models

model = models.densenet121(weights='DEFAULT')

labels = ['Emphysema', 
          'Hernia', 
          'Mass', 
          'Pneumonia',  
          'Edema']

n_classes = len(labels)

model.classifier = nn.Linear(model.classifier.in_features, n_classes)
model
# Out:
# Downloading: "https://download.pytorch.org/models/densenet121-a639ec97.pth" to /root/.cache/torch/hub/checkpoints/densenet121-a639ec97.pth
# 100%|██████████| 30.8M/30.8M [00:00<00:00, 170MB/s]
# DenseNet(
#   (features): Sequential(
#     (conv0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (norm0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu0): ReLU(inplace=True)
#     (pool0): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (denseblock1): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(96, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(160, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(224, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition1): _Transition(
#       (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock2): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(160, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(224, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(288, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(320, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(352, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(416, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(416, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(448, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(480, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition2): _Transition(
#       (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock3): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(288, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(320, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(352, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(416, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(416, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(448, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(480, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(544, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(544, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(576, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(608, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer13): _DenseLayer(
#         (norm1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(640, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer14): _DenseLayer(
#         (norm1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(672, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer15): _DenseLayer(
#         (norm1): BatchNorm2d(704, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(704, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer16): _DenseLayer(
#         (norm1): BatchNorm2d(736, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(736, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer17): _DenseLayer(
#         (norm1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer18): _DenseLayer(
#         (norm1): BatchNorm2d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(800, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer19): _DenseLayer(
#         (norm1): BatchNorm2d(832, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer20): _DenseLayer(
#         (norm1): BatchNorm2d(864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(864, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer21): _DenseLayer(
#         (norm1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer22): _DenseLayer(
#         (norm1): BatchNorm2d(928, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(928, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer23): _DenseLayer(
#         (norm1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(960, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer24): _DenseLayer(
#         (norm1): BatchNorm2d(992, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(992, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition3): _Transition(
#       (norm): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock4): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(544, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(544, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(576, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(608, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(640, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(672, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(704, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(704, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(736, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(736, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(800, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(832, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(864, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer13): _DenseLayer(
#         (norm1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer14): _DenseLayer(
#         (norm1): BatchNorm2d(928, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(928, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer15): _DenseLayer(
#         (norm1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(960, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer16): _DenseLayer(
#         (norm1): BatchNorm2d(992, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(992, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (norm5): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (classifier): Linear(in_features=1024, out_features=5, bias=True)
# )

# %%
for i, (name, module) in enumerate(model.named_modules()):
    print(f"Layer {i}: Name: {name}, Type: {type(module).__name__}")
# Out:
# Layer 0: Name: , Type: DenseNet
# Layer 1: Name: features, Type: Sequential
# Layer 2: Name: features.conv0, Type: Conv2d
# Layer 3: Name: features.norm0, Type: BatchNorm2d
# Layer 4: Name: features.relu0, Type: ReLU
# Layer 5: Name: features.pool0, Type: MaxPool2d
# Layer 6: Name: features.denseblock1, Type: _DenseBlock
# Layer 7: Name: features.denseblock1.denselayer1, Type: _DenseLayer
# Layer 8: Name: features.denseblock1.denselayer1.norm1, Type: BatchNorm2d
# Layer 9: Name: features.denseblock1.denselayer1.relu1, Type: ReLU
# Layer 10: Name: features.denseblock1.denselayer1.conv1, Type: Conv2d
# Layer 11: Name: features.denseblock1.denselayer1.norm2, Type: BatchNorm2d
# Layer 12: Name: features.denseblock1.denselayer1.relu2, Type: ReLU
# Layer 13: Name: features.denseblock1.denselayer1.conv2, Type: Conv2d
# Layer 14: Name: features.denseblock1.denselayer2, Type: _DenseLayer
# Layer 15: Name: features.denseblock1.denselayer2.norm1, Type: BatchNorm2d
# Layer 16: Name: features.denseblock1.denselayer2.relu1, Type: ReLU
# Layer 17: Name: features.denseblock1.denselayer2.conv1, Type: Conv2d
# Layer 18: Name: features.denseblock1.denselayer2.norm2, Type: BatchNorm2d
# Layer 19: Name: features.denseblock1.denselayer2.relu2, Type: ReLU
# Layer 20: Name: features.denseblock1.denselayer2.conv2, Type: Conv2d
# Layer 21: Name: features.denseblock1.denselayer3, Type: _DenseLayer
# Layer 22: Name: features.denseblock1.denselayer3.norm1, Type: BatchNorm2d
# Layer 23: Name: features.denseblock1.denselayer3.relu1, Type: ReLU
# Layer 24: Name: features.denseblock1.denselayer3.conv1, Type: Conv2d
# Layer 25: Name: features.denseblock1.denselayer3.norm2, Type: BatchNorm2d
# Layer 26: Name: features.denseblock1.denselayer3.relu2, Type: ReLU
# Layer 27: Name: features.denseblock1.denselayer3.conv2, Type: Conv2d
# Layer 28: Name: features.denseblock1.denselayer4, Type: _DenseLayer
# Layer 29: Name: features.denseblock1.denselayer4.norm1, Type: BatchNorm2d
# Layer 30: Name: features.denseblock1.denselayer4.relu1, Type: ReLU
# Layer 31: Name: features.denseblock1.denselayer4.conv1, Type: Conv2d
# Layer 32: Name: features.denseblock1.denselayer4.norm2, Type: BatchNorm2d
# Layer 33: Name: features.denseblock1.denselayer4.relu2, Type: ReLU
# Layer 34: Name: features.denseblock1.denselayer4.conv2, Type: Conv2d
# Layer 35: Name: features.denseblock1.denselayer5, Type: _DenseLayer
# Layer 36: Name: features.denseblock1.denselayer5.norm1, Type: BatchNorm2d
# Layer 37: Name: features.denseblock1.denselayer5.relu1, Type: ReLU
# Layer 38: Name: features.denseblock1.denselayer5.conv1, Type: Conv2d
# Layer 39: Name: features.denseblock1.denselayer5.norm2, Type: BatchNorm2d
# Layer 40: Name: features.denseblock1.denselayer5.relu2, Type: ReLU
# Layer 41: Name: features.denseblock1.denselayer5.conv2, Type: Conv2d
# Layer 42: Name: features.denseblock1.denselayer6, Type: _DenseLayer
# Layer 43: Name: features.denseblock1.denselayer6.norm1, Type: BatchNorm2d
# Layer 44: Name: features.denseblock1.denselayer6.relu1, Type: ReLU
# Layer 45: Name: features.denseblock1.denselayer6.conv1, Type: Conv2d
# Layer 46: Name: features.denseblock1.denselayer6.norm2, Type: BatchNorm2d
# Layer 47: Name: features.denseblock1.denselayer6.relu2, Type: ReLU
# Layer 48: Name: features.denseblock1.denselayer6.conv2, Type: Conv2d
# Layer 49: Name: features.transition1, Type: _Transition
# Layer 50: Name: features.transition1.norm, Type: BatchNorm2d
# Layer 51: Name: features.transition1.relu, Type: ReLU
# Layer 52: Name: features.transition1.conv, Type: Conv2d
# Layer 53: Name: features.transition1.pool, Type: AvgPool2d
# Layer 54: Name: features.denseblock2, Type: _DenseBlock
# Layer 55: Name: features.denseblock2.denselayer1, Type: _DenseLayer
# Layer 56: Name: features.denseblock2.denselayer1.norm1, Type: BatchNorm2d
# Layer 57: Name: features.denseblock2.denselayer1.relu1, Type: ReLU
# Layer 58: Name: features.denseblock2.denselayer1.conv1, Type: Conv2d
# Layer 59: Name: features.denseblock2.denselayer1.norm2, Type: BatchNorm2d
# Layer 60: Name: features.denseblock2.denselayer1.relu2, Type: ReLU
# Layer 61: Name: features.denseblock2.denselayer1.conv2, Type: Conv2d
# Layer 62: Name: features.denseblock2.denselayer2, Type: _DenseLayer
# Layer 63: Name: features.denseblock2.denselayer2.norm1, Type: BatchNorm2d
# Layer 64: Name: features.denseblock2.denselayer2.relu1, Type: ReLU
# Layer 65: Name: features.denseblock2.denselayer2.conv1, Type: Conv2d
# Layer 66: Name: features.denseblock2.denselayer2.norm2, Type: BatchNorm2d
# Layer 67: Name: features.denseblock2.denselayer2.relu2, Type: ReLU
# Layer 68: Name: features.denseblock2.denselayer2.conv2, Type: Conv2d
# Layer 69: Name: features.denseblock2.denselayer3, Type: _DenseLayer
# Layer 70: Name: features.denseblock2.denselayer3.norm1, Type: BatchNorm2d
# Layer 71: Name: features.denseblock2.denselayer3.relu1, Type: ReLU
# Layer 72: Name: features.denseblock2.denselayer3.conv1, Type: Conv2d
# Layer 73: Name: features.denseblock2.denselayer3.norm2, Type: BatchNorm2d
# Layer 74: Name: features.denseblock2.denselayer3.relu2, Type: ReLU
# Layer 75: Name: features.denseblock2.denselayer3.conv2, Type: Conv2d
# Layer 76: Name: features.denseblock2.denselayer4, Type: _DenseLayer
# Layer 77: Name: features.denseblock2.denselayer4.norm1, Type: BatchNorm2d
# Layer 78: Name: features.denseblock2.denselayer4.relu1, Type: ReLU
# Layer 79: Name: features.denseblock2.denselayer4.conv1, Type: Conv2d
# Layer 80: Name: features.denseblock2.denselayer4.norm2, Type: BatchNorm2d
# Layer 81: Name: features.denseblock2.denselayer4.relu2, Type: ReLU
# Layer 82: Name: features.denseblock2.denselayer4.conv2, Type: Conv2d
# Layer 83: Name: features.denseblock2.denselayer5, Type: _DenseLayer
# Layer 84: Name: features.denseblock2.denselayer5.norm1, Type: BatchNorm2d
# Layer 85: Name: features.denseblock2.denselayer5.relu1, Type: ReLU
# Layer 86: Name: features.denseblock2.denselayer5.conv1, Type: Conv2d
# Layer 87: Name: features.denseblock2.denselayer5.norm2, Type: BatchNorm2d
# Layer 88: Name: features.denseblock2.denselayer5.relu2, Type: ReLU
# Layer 89: Name: features.denseblock2.denselayer5.conv2, Type: Conv2d
# Layer 90: Name: features.denseblock2.denselayer6, Type: _DenseLayer
# Layer 91: Name: features.denseblock2.denselayer6.norm1, Type: BatchNorm2d
# Layer 92: Name: features.denseblock2.denselayer6.relu1, Type: ReLU
# Layer 93: Name: features.denseblock2.denselayer6.conv1, Type: Conv2d
# Layer 94: Name: features.denseblock2.denselayer6.norm2, Type: BatchNorm2d
# Layer 95: Name: features.denseblock2.denselayer6.relu2, Type: ReLU
# Layer 96: Name: features.denseblock2.denselayer6.conv2, Type: Conv2d
# Layer 97: Name: features.denseblock2.denselayer7, Type: _DenseLayer
# Layer 98: Name: features.denseblock2.denselayer7.norm1, Type: BatchNorm2d
# Layer 99: Name: features.denseblock2.denselayer7.relu1, Type: ReLU
# Layer 100: Name: features.denseblock2.denselayer7.conv1, Type: Conv2d
# Layer 101: Name: features.denseblock2.denselayer7.norm2, Type: BatchNorm2d
# Layer 102: Name: features.denseblock2.denselayer7.relu2, Type: ReLU
# Layer 103: Name: features.denseblock2.denselayer7.conv2, Type: Conv2d
# Layer 104: Name: features.denseblock2.denselayer8, Type: _DenseLayer
# Layer 105: Name: features.denseblock2.denselayer8.norm1, Type: BatchNorm2d
# Layer 106: Name: features.denseblock2.denselayer8.relu1, Type: ReLU
# Layer 107: Name: features.denseblock2.denselayer8.conv1, Type: Conv2d
# Layer 108: Name: features.denseblock2.denselayer8.norm2, Type: BatchNorm2d
# Layer 109: Name: features.denseblock2.denselayer8.relu2, Type: ReLU
# Layer 110: Name: features.denseblock2.denselayer8.conv2, Type: Conv2d
# Layer 111: Name: features.denseblock2.denselayer9, Type: _DenseLayer
# Layer 112: Name: features.denseblock2.denselayer9.norm1, Type: BatchNorm2d
# Layer 113: Name: features.denseblock2.denselayer9.relu1, Type: ReLU
# Layer 114: Name: features.denseblock2.denselayer9.conv1, Type: Conv2d
# Layer 115: Name: features.denseblock2.denselayer9.norm2, Type: BatchNorm2d
# Layer 116: Name: features.denseblock2.denselayer9.relu2, Type: ReLU
# Layer 117: Name: features.denseblock2.denselayer9.conv2, Type: Conv2d
# Layer 118: Name: features.denseblock2.denselayer10, Type: _DenseLayer
# Layer 119: Name: features.denseblock2.denselayer10.norm1, Type: BatchNorm2d
# Layer 120: Name: features.denseblock2.denselayer10.relu1, Type: ReLU
# Layer 121: Name: features.denseblock2.denselayer10.conv1, Type: Conv2d
# Layer 122: Name: features.denseblock2.denselayer10.norm2, Type: BatchNorm2d
# Layer 123: Name: features.denseblock2.denselayer10.relu2, Type: ReLU
# Layer 124: Name: features.denseblock2.denselayer10.conv2, Type: Conv2d
# Layer 125: Name: features.denseblock2.denselayer11, Type: _DenseLayer
# Layer 126: Name: features.denseblock2.denselayer11.norm1, Type: BatchNorm2d
# Layer 127: Name: features.denseblock2.denselayer11.relu1, Type: ReLU
# Layer 128: Name: features.denseblock2.denselayer11.conv1, Type: Conv2d
# Layer 129: Name: features.denseblock2.denselayer11.norm2, Type: BatchNorm2d
# Layer 130: Name: features.denseblock2.denselayer11.relu2, Type: ReLU
# Layer 131: Name: features.denseblock2.denselayer11.conv2, Type: Conv2d
# Layer 132: Name: features.denseblock2.denselayer12, Type: _DenseLayer
# Layer 133: Name: features.denseblock2.denselayer12.norm1, Type: BatchNorm2d
# Layer 134: Name: features.denseblock2.denselayer12.relu1, Type: ReLU
# Layer 135: Name: features.denseblock2.denselayer12.conv1, Type: Conv2d
# Layer 136: Name: features.denseblock2.denselayer12.norm2, Type: BatchNorm2d
# Layer 137: Name: features.denseblock2.denselayer12.relu2, Type: ReLU
# Layer 138: Name: features.denseblock2.denselayer12.conv2, Type: Conv2d
# Layer 139: Name: features.transition2, Type: _Transition
# Layer 140: Name: features.transition2.norm, Type: BatchNorm2d
# Layer 141: Name: features.transition2.relu, Type: ReLU
# Layer 142: Name: features.transition2.conv, Type: Conv2d
# Layer 143: Name: features.transition2.pool, Type: AvgPool2d
# Layer 144: Name: features.denseblock3, Type: _DenseBlock
# Layer 145: Name: features.denseblock3.denselayer1, Type: _DenseLayer
# Layer 146: Name: features.denseblock3.denselayer1.norm1, Type: BatchNorm2d
# Layer 147: Name: features.denseblock3.denselayer1.relu1, Type: ReLU
# Layer 148: Name: features.denseblock3.denselayer1.conv1, Type: Conv2d
# Layer 149: Name: features.denseblock3.denselayer1.norm2, Type: BatchNorm2d
# Layer 150: Name: features.denseblock3.denselayer1.relu2, Type: ReLU
# Layer 151: Name: features.denseblock3.denselayer1.conv2, Type: Conv2d
# Layer 152: Name: features.denseblock3.denselayer2, Type: _DenseLayer
# Layer 153: Name: features.denseblock3.denselayer2.norm1, Type: BatchNorm2d
# Layer 154: Name: features.denseblock3.denselayer2.relu1, Type: ReLU
# Layer 155: Name: features.denseblock3.denselayer2.conv1, Type: Conv2d
# Layer 156: Name: features.denseblock3.denselayer2.norm2, Type: BatchNorm2d
# Layer 157: Name: features.denseblock3.denselayer2.relu2, Type: ReLU
# Layer 158: Name: features.denseblock3.denselayer2.conv2, Type: Conv2d
# Layer 159: Name: features.denseblock3.denselayer3, Type: _DenseLayer
# Layer 160: Name: features.denseblock3.denselayer3.norm1, Type: BatchNorm2d
# Layer 161: Name: features.denseblock3.denselayer3.relu1, Type: ReLU
# Layer 162: Name: features.denseblock3.denselayer3.conv1, Type: Conv2d
# Layer 163: Name: features.denseblock3.denselayer3.norm2, Type: BatchNorm2d
# Layer 164: Name: features.denseblock3.denselayer3.relu2, Type: ReLU
# Layer 165: Name: features.denseblock3.denselayer3.conv2, Type: Conv2d
# Layer 166: Name: features.denseblock3.denselayer4, Type: _DenseLayer
# Layer 167: Name: features.denseblock3.denselayer4.norm1, Type: BatchNorm2d
# Layer 168: Name: features.denseblock3.denselayer4.relu1, Type: ReLU
# Layer 169: Name: features.denseblock3.denselayer4.conv1, Type: Conv2d
# Layer 170: Name: features.denseblock3.denselayer4.norm2, Type: BatchNorm2d
# Layer 171: Name: features.denseblock3.denselayer4.relu2, Type: ReLU
# Layer 172: Name: features.denseblock3.denselayer4.conv2, Type: Conv2d
# Layer 173: Name: features.denseblock3.denselayer5, Type: _DenseLayer
# Layer 174: Name: features.denseblock3.denselayer5.norm1, Type: BatchNorm2d
# Layer 175: Name: features.denseblock3.denselayer5.relu1, Type: ReLU
# Layer 176: Name: features.denseblock3.denselayer5.conv1, Type: Conv2d
# Layer 177: Name: features.denseblock3.denselayer5.norm2, Type: BatchNorm2d
# Layer 178: Name: features.denseblock3.denselayer5.relu2, Type: ReLU
# Layer 179: Name: features.denseblock3.denselayer5.conv2, Type: Conv2d
# Layer 180: Name: features.denseblock3.denselayer6, Type: _DenseLayer
# Layer 181: Name: features.denseblock3.denselayer6.norm1, Type: BatchNorm2d
# Layer 182: Name: features.denseblock3.denselayer6.relu1, Type: ReLU
# Layer 183: Name: features.denseblock3.denselayer6.conv1, Type: Conv2d
# Layer 184: Name: features.denseblock3.denselayer6.norm2, Type: BatchNorm2d
# Layer 185: Name: features.denseblock3.denselayer6.relu2, Type: ReLU
# Layer 186: Name: features.denseblock3.denselayer6.conv2, Type: Conv2d
# Layer 187: Name: features.denseblock3.denselayer7, Type: _DenseLayer
# Layer 188: Name: features.denseblock3.denselayer7.norm1, Type: BatchNorm2d
# Layer 189: Name: features.denseblock3.denselayer7.relu1, Type: ReLU
# Layer 190: Name: features.denseblock3.denselayer7.conv1, Type: Conv2d
# Layer 191: Name: features.denseblock3.denselayer7.norm2, Type: BatchNorm2d
# Layer 192: Name: features.denseblock3.denselayer7.relu2, Type: ReLU
# Layer 193: Name: features.denseblock3.denselayer7.conv2, Type: Conv2d
# Layer 194: Name: features.denseblock3.denselayer8, Type: _DenseLayer
# Layer 195: Name: features.denseblock3.denselayer8.norm1, Type: BatchNorm2d
# Layer 196: Name: features.denseblock3.denselayer8.relu1, Type: ReLU
# Layer 197: Name: features.denseblock3.denselayer8.conv1, Type: Conv2d
# Layer 198: Name: features.denseblock3.denselayer8.norm2, Type: BatchNorm2d
# Layer 199: Name: features.denseblock3.denselayer8.relu2, Type: ReLU
# Layer 200: Name: features.denseblock3.denselayer8.conv2, Type: Conv2d
# Layer 201: Name: features.denseblock3.denselayer9, Type: _DenseLayer
# Layer 202: Name: features.denseblock3.denselayer9.norm1, Type: BatchNorm2d
# Layer 203: Name: features.denseblock3.denselayer9.relu1, Type: ReLU
# Layer 204: Name: features.denseblock3.denselayer9.conv1, Type: Conv2d
# Layer 205: Name: features.denseblock3.denselayer9.norm2, Type: BatchNorm2d
# Layer 206: Name: features.denseblock3.denselayer9.relu2, Type: ReLU
# Layer 207: Name: features.denseblock3.denselayer9.conv2, Type: Conv2d
# Layer 208: Name: features.denseblock3.denselayer10, Type: _DenseLayer
# Layer 209: Name: features.denseblock3.denselayer10.norm1, Type: BatchNorm2d
# Layer 210: Name: features.denseblock3.denselayer10.relu1, Type: ReLU
# Layer 211: Name: features.denseblock3.denselayer10.conv1, Type: Conv2d
# Layer 212: Name: features.denseblock3.denselayer10.norm2, Type: BatchNorm2d
# Layer 213: Name: features.denseblock3.denselayer10.relu2, Type: ReLU
# Layer 214: Name: features.denseblock3.denselayer10.conv2, Type: Conv2d
# Layer 215: Name: features.denseblock3.denselayer11, Type: _DenseLayer
# Layer 216: Name: features.denseblock3.denselayer11.norm1, Type: BatchNorm2d
# Layer 217: Name: features.denseblock3.denselayer11.relu1, Type: ReLU
# Layer 218: Name: features.denseblock3.denselayer11.conv1, Type: Conv2d
# Layer 219: Name: features.denseblock3.denselayer11.norm2, Type: BatchNorm2d
# Layer 220: Name: features.denseblock3.denselayer11.relu2, Type: ReLU
# Layer 221: Name: features.denseblock3.denselayer11.conv2, Type: Conv2d
# Layer 222: Name: features.denseblock3.denselayer12, Type: _DenseLayer
# Layer 223: Name: features.denseblock3.denselayer12.norm1, Type: BatchNorm2d
# Layer 224: Name: features.denseblock3.denselayer12.relu1, Type: ReLU
# Layer 225: Name: features.denseblock3.denselayer12.conv1, Type: Conv2d
# Layer 226: Name: features.denseblock3.denselayer12.norm2, Type: BatchNorm2d
# Layer 227: Name: features.denseblock3.denselayer12.relu2, Type: ReLU
# Layer 228: Name: features.denseblock3.denselayer12.conv2, Type: Conv2d
# Layer 229: Name: features.denseblock3.denselayer13, Type: _DenseLayer
# Layer 230: Name: features.denseblock3.denselayer13.norm1, Type: BatchNorm2d
# Layer 231: Name: features.denseblock3.denselayer13.relu1, Type: ReLU
# Layer 232: Name: features.denseblock3.denselayer13.conv1, Type: Conv2d
# Layer 233: Name: features.denseblock3.denselayer13.norm2, Type: BatchNorm2d
# Layer 234: Name: features.denseblock3.denselayer13.relu2, Type: ReLU
# Layer 235: Name: features.denseblock3.denselayer13.conv2, Type: Conv2d
# Layer 236: Name: features.denseblock3.denselayer14, Type: _DenseLayer
# Layer 237: Name: features.denseblock3.denselayer14.norm1, Type: BatchNorm2d
# Layer 238: Name: features.denseblock3.denselayer14.relu1, Type: ReLU
# Layer 239: Name: features.denseblock3.denselayer14.conv1, Type: Conv2d
# Layer 240: Name: features.denseblock3.denselayer14.norm2, Type: BatchNorm2d
# Layer 241: Name: features.denseblock3.denselayer14.relu2, Type: ReLU
# Layer 242: Name: features.denseblock3.denselayer14.conv2, Type: Conv2d
# Layer 243: Name: features.denseblock3.denselayer15, Type: _DenseLayer
# Layer 244: Name: features.denseblock3.denselayer15.norm1, Type: BatchNorm2d
# Layer 245: Name: features.denseblock3.denselayer15.relu1, Type: ReLU
# Layer 246: Name: features.denseblock3.denselayer15.conv1, Type: Conv2d
# Layer 247: Name: features.denseblock3.denselayer15.norm2, Type: BatchNorm2d
# Layer 248: Name: features.denseblock3.denselayer15.relu2, Type: ReLU
# Layer 249: Name: features.denseblock3.denselayer15.conv2, Type: Conv2d
# Layer 250: Name: features.denseblock3.denselayer16, Type: _DenseLayer
# Layer 251: Name: features.denseblock3.denselayer16.norm1, Type: BatchNorm2d
# Layer 252: Name: features.denseblock3.denselayer16.relu1, Type: ReLU
# Layer 253: Name: features.denseblock3.denselayer16.conv1, Type: Conv2d
# Layer 254: Name: features.denseblock3.denselayer16.norm2, Type: BatchNorm2d
# Layer 255: Name: features.denseblock3.denselayer16.relu2, Type: ReLU
# Layer 256: Name: features.denseblock3.denselayer16.conv2, Type: Conv2d
# Layer 257: Name: features.denseblock3.denselayer17, Type: _DenseLayer
# Layer 258: Name: features.denseblock3.denselayer17.norm1, Type: BatchNorm2d
# Layer 259: Name: features.denseblock3.denselayer17.relu1, Type: ReLU
# Layer 260: Name: features.denseblock3.denselayer17.conv1, Type: Conv2d
# Layer 261: Name: features.denseblock3.denselayer17.norm2, Type: BatchNorm2d
# Layer 262: Name: features.denseblock3.denselayer17.relu2, Type: ReLU
# Layer 263: Name: features.denseblock3.denselayer17.conv2, Type: Conv2d
# Layer 264: Name: features.denseblock3.denselayer18, Type: _DenseLayer
# Layer 265: Name: features.denseblock3.denselayer18.norm1, Type: BatchNorm2d
# Layer 266: Name: features.denseblock3.denselayer18.relu1, Type: ReLU
# Layer 267: Name: features.denseblock3.denselayer18.conv1, Type: Conv2d
# Layer 268: Name: features.denseblock3.denselayer18.norm2, Type: BatchNorm2d
# Layer 269: Name: features.denseblock3.denselayer18.relu2, Type: ReLU
# Layer 270: Name: features.denseblock3.denselayer18.conv2, Type: Conv2d
# Layer 271: Name: features.denseblock3.denselayer19, Type: _DenseLayer
# Layer 272: Name: features.denseblock3.denselayer19.norm1, Type: BatchNorm2d
# Layer 273: Name: features.denseblock3.denselayer19.relu1, Type: ReLU
# Layer 274: Name: features.denseblock3.denselayer19.conv1, Type: Conv2d
# Layer 275: Name: features.denseblock3.denselayer19.norm2, Type: BatchNorm2d
# Layer 276: Name: features.denseblock3.denselayer19.relu2, Type: ReLU
# Layer 277: Name: features.denseblock3.denselayer19.conv2, Type: Conv2d
# Layer 278: Name: features.denseblock3.denselayer20, Type: _DenseLayer
# Layer 279: Name: features.denseblock3.denselayer20.norm1, Type: BatchNorm2d
# Layer 280: Name: features.denseblock3.denselayer20.relu1, Type: ReLU
# Layer 281: Name: features.denseblock3.denselayer20.conv1, Type: Conv2d
# Layer 282: Name: features.denseblock3.denselayer20.norm2, Type: BatchNorm2d
# Layer 283: Name: features.denseblock3.denselayer20.relu2, Type: ReLU
# Layer 284: Name: features.denseblock3.denselayer20.conv2, Type: Conv2d
# Layer 285: Name: features.denseblock3.denselayer21, Type: _DenseLayer
# Layer 286: Name: features.denseblock3.denselayer21.norm1, Type: BatchNorm2d
# Layer 287: Name: features.denseblock3.denselayer21.relu1, Type: ReLU
# Layer 288: Name: features.denseblock3.denselayer21.conv1, Type: Conv2d
# Layer 289: Name: features.denseblock3.denselayer21.norm2, Type: BatchNorm2d
# Layer 290: Name: features.denseblock3.denselayer21.relu2, Type: ReLU
# Layer 291: Name: features.denseblock3.denselayer21.conv2, Type: Conv2d
# Layer 292: Name: features.denseblock3.denselayer22, Type: _DenseLayer
# Layer 293: Name: features.denseblock3.denselayer22.norm1, Type: BatchNorm2d
# Layer 294: Name: features.denseblock3.denselayer22.relu1, Type: ReLU
# Layer 295: Name: features.denseblock3.denselayer22.conv1, Type: Conv2d
# Layer 296: Name: features.denseblock3.denselayer22.norm2, Type: BatchNorm2d
# Layer 297: Name: features.denseblock3.denselayer22.relu2, Type: ReLU
# Layer 298: Name: features.denseblock3.denselayer22.conv2, Type: Conv2d
# Layer 299: Name: features.denseblock3.denselayer23, Type: _DenseLayer
# Layer 300: Name: features.denseblock3.denselayer23.norm1, Type: BatchNorm2d
# Layer 301: Name: features.denseblock3.denselayer23.relu1, Type: ReLU
# Layer 302: Name: features.denseblock3.denselayer23.conv1, Type: Conv2d
# Layer 303: Name: features.denseblock3.denselayer23.norm2, Type: BatchNorm2d
# Layer 304: Name: features.denseblock3.denselayer23.relu2, Type: ReLU
# Layer 305: Name: features.denseblock3.denselayer23.conv2, Type: Conv2d
# Layer 306: Name: features.denseblock3.denselayer24, Type: _DenseLayer
# Layer 307: Name: features.denseblock3.denselayer24.norm1, Type: BatchNorm2d
# Layer 308: Name: features.denseblock3.denselayer24.relu1, Type: ReLU
# Layer 309: Name: features.denseblock3.denselayer24.conv1, Type: Conv2d
# Layer 310: Name: features.denseblock3.denselayer24.norm2, Type: BatchNorm2d
# Layer 311: Name: features.denseblock3.denselayer24.relu2, Type: ReLU
# Layer 312: Name: features.denseblock3.denselayer24.conv2, Type: Conv2d
# Layer 313: Name: features.transition3, Type: _Transition
# Layer 314: Name: features.transition3.norm, Type: BatchNorm2d
# Layer 315: Name: features.transition3.relu, Type: ReLU
# Layer 316: Name: features.transition3.conv, Type: Conv2d
# Layer 317: Name: features.transition3.pool, Type: AvgPool2d
# Layer 318: Name: features.denseblock4, Type: _DenseBlock
# Layer 319: Name: features.denseblock4.denselayer1, Type: _DenseLayer
# Layer 320: Name: features.denseblock4.denselayer1.norm1, Type: BatchNorm2d
# Layer 321: Name: features.denseblock4.denselayer1.relu1, Type: ReLU
# Layer 322: Name: features.denseblock4.denselayer1.conv1, Type: Conv2d
# Layer 323: Name: features.denseblock4.denselayer1.norm2, Type: BatchNorm2d
# Layer 324: Name: features.denseblock4.denselayer1.relu2, Type: ReLU
# Layer 325: Name: features.denseblock4.denselayer1.conv2, Type: Conv2d
# Layer 326: Name: features.denseblock4.denselayer2, Type: _DenseLayer
# Layer 327: Name: features.denseblock4.denselayer2.norm1, Type: BatchNorm2d
# Layer 328: Name: features.denseblock4.denselayer2.relu1, Type: ReLU
# Layer 329: Name: features.denseblock4.denselayer2.conv1, Type: Conv2d
# Layer 330: Name: features.denseblock4.denselayer2.norm2, Type: BatchNorm2d
# Layer 331: Name: features.denseblock4.denselayer2.relu2, Type: ReLU
# Layer 332: Name: features.denseblock4.denselayer2.conv2, Type: Conv2d
# Layer 333: Name: features.denseblock4.denselayer3, Type: _DenseLayer
# Layer 334: Name: features.denseblock4.denselayer3.norm1, Type: BatchNorm2d
# Layer 335: Name: features.denseblock4.denselayer3.relu1, Type: ReLU
# Layer 336: Name: features.denseblock4.denselayer3.conv1, Type: Conv2d
# Layer 337: Name: features.denseblock4.denselayer3.norm2, Type: BatchNorm2d
# Layer 338: Name: features.denseblock4.denselayer3.relu2, Type: ReLU
# Layer 339: Name: features.denseblock4.denselayer3.conv2, Type: Conv2d
# Layer 340: Name: features.denseblock4.denselayer4, Type: _DenseLayer
# Layer 341: Name: features.denseblock4.denselayer4.norm1, Type: BatchNorm2d
# Layer 342: Name: features.denseblock4.denselayer4.relu1, Type: ReLU
# Layer 343: Name: features.denseblock4.denselayer4.conv1, Type: Conv2d
# Layer 344: Name: features.denseblock4.denselayer4.norm2, Type: BatchNorm2d
# Layer 345: Name: features.denseblock4.denselayer4.relu2, Type: ReLU
# Layer 346: Name: features.denseblock4.denselayer4.conv2, Type: Conv2d
# Layer 347: Name: features.denseblock4.denselayer5, Type: _DenseLayer
# Layer 348: Name: features.denseblock4.denselayer5.norm1, Type: BatchNorm2d
# Layer 349: Name: features.denseblock4.denselayer5.relu1, Type: ReLU
# Layer 350: Name: features.denseblock4.denselayer5.conv1, Type: Conv2d
# Layer 351: Name: features.denseblock4.denselayer5.norm2, Type: BatchNorm2d
# Layer 352: Name: features.denseblock4.denselayer5.relu2, Type: ReLU
# Layer 353: Name: features.denseblock4.denselayer5.conv2, Type: Conv2d
# Layer 354: Name: features.denseblock4.denselayer6, Type: _DenseLayer
# Layer 355: Name: features.denseblock4.denselayer6.norm1, Type: BatchNorm2d
# Layer 356: Name: features.denseblock4.denselayer6.relu1, Type: ReLU
# Layer 357: Name: features.denseblock4.denselayer6.conv1, Type: Conv2d
# Layer 358: Name: features.denseblock4.denselayer6.norm2, Type: BatchNorm2d
# Layer 359: Name: features.denseblock4.denselayer6.relu2, Type: ReLU
# Layer 360: Name: features.denseblock4.denselayer6.conv2, Type: Conv2d
# Layer 361: Name: features.denseblock4.denselayer7, Type: _DenseLayer
# Layer 362: Name: features.denseblock4.denselayer7.norm1, Type: BatchNorm2d
# Layer 363: Name: features.denseblock4.denselayer7.relu1, Type: ReLU
# Layer 364: Name: features.denseblock4.denselayer7.conv1, Type: Conv2d
# Layer 365: Name: features.denseblock4.denselayer7.norm2, Type: BatchNorm2d
# Layer 366: Name: features.denseblock4.denselayer7.relu2, Type: ReLU
# Layer 367: Name: features.denseblock4.denselayer7.conv2, Type: Conv2d
# Layer 368: Name: features.denseblock4.denselayer8, Type: _DenseLayer
# Layer 369: Name: features.denseblock4.denselayer8.norm1, Type: BatchNorm2d
# Layer 370: Name: features.denseblock4.denselayer8.relu1, Type: ReLU
# Layer 371: Name: features.denseblock4.denselayer8.conv1, Type: Conv2d
# Layer 372: Name: features.denseblock4.denselayer8.norm2, Type: BatchNorm2d
# Layer 373: Name: features.denseblock4.denselayer8.relu2, Type: ReLU
# Layer 374: Name: features.denseblock4.denselayer8.conv2, Type: Conv2d
# Layer 375: Name: features.denseblock4.denselayer9, Type: _DenseLayer
# Layer 376: Name: features.denseblock4.denselayer9.norm1, Type: BatchNorm2d
# Layer 377: Name: features.denseblock4.denselayer9.relu1, Type: ReLU
# Layer 378: Name: features.denseblock4.denselayer9.conv1, Type: Conv2d
# Layer 379: Name: features.denseblock4.denselayer9.norm2, Type: BatchNorm2d
# Layer 380: Name: features.denseblock4.denselayer9.relu2, Type: ReLU
# Layer 381: Name: features.denseblock4.denselayer9.conv2, Type: Conv2d
# Layer 382: Name: features.denseblock4.denselayer10, Type: _DenseLayer
# Layer 383: Name: features.denseblock4.denselayer10.norm1, Type: BatchNorm2d
# Layer 384: Name: features.denseblock4.denselayer10.relu1, Type: ReLU
# Layer 385: Name: features.denseblock4.denselayer10.conv1, Type: Conv2d
# Layer 386: Name: features.denseblock4.denselayer10.norm2, Type: BatchNorm2d
# Layer 387: Name: features.denseblock4.denselayer10.relu2, Type: ReLU
# Layer 388: Name: features.denseblock4.denselayer10.conv2, Type: Conv2d
# Layer 389: Name: features.denseblock4.denselayer11, Type: _DenseLayer
# Layer 390: Name: features.denseblock4.denselayer11.norm1, Type: BatchNorm2d
# Layer 391: Name: features.denseblock4.denselayer11.relu1, Type: ReLU
# Layer 392: Name: features.denseblock4.denselayer11.conv1, Type: Conv2d
# Layer 393: Name: features.denseblock4.denselayer11.norm2, Type: BatchNorm2d
# Layer 394: Name: features.denseblock4.denselayer11.relu2, Type: ReLU
# Layer 395: Name: features.denseblock4.denselayer11.conv2, Type: Conv2d
# Layer 396: Name: features.denseblock4.denselayer12, Type: _DenseLayer
# Layer 397: Name: features.denseblock4.denselayer12.norm1, Type: BatchNorm2d
# Layer 398: Name: features.denseblock4.denselayer12.relu1, Type: ReLU
# Layer 399: Name: features.denseblock4.denselayer12.conv1, Type: Conv2d
# Layer 400: Name: features.denseblock4.denselayer12.norm2, Type: BatchNorm2d
# Layer 401: Name: features.denseblock4.denselayer12.relu2, Type: ReLU
# Layer 402: Name: features.denseblock4.denselayer12.conv2, Type: Conv2d
# Layer 403: Name: features.denseblock4.denselayer13, Type: _DenseLayer
# Layer 404: Name: features.denseblock4.denselayer13.norm1, Type: BatchNorm2d
# Layer 405: Name: features.denseblock4.denselayer13.relu1, Type: ReLU
# Layer 406: Name: features.denseblock4.denselayer13.conv1, Type: Conv2d
# Layer 407: Name: features.denseblock4.denselayer13.norm2, Type: BatchNorm2d
# Layer 408: Name: features.denseblock4.denselayer13.relu2, Type: ReLU
# Layer 409: Name: features.denseblock4.denselayer13.conv2, Type: Conv2d
# Layer 410: Name: features.denseblock4.denselayer14, Type: _DenseLayer
# Layer 411: Name: features.denseblock4.denselayer14.norm1, Type: BatchNorm2d
# Layer 412: Name: features.denseblock4.denselayer14.relu1, Type: ReLU
# Layer 413: Name: features.denseblock4.denselayer14.conv1, Type: Conv2d
# Layer 414: Name: features.denseblock4.denselayer14.norm2, Type: BatchNorm2d
# Layer 415: Name: features.denseblock4.denselayer14.relu2, Type: ReLU
# Layer 416: Name: features.denseblock4.denselayer14.conv2, Type: Conv2d
# Layer 417: Name: features.denseblock4.denselayer15, Type: _DenseLayer
# Layer 418: Name: features.denseblock4.denselayer15.norm1, Type: BatchNorm2d
# Layer 419: Name: features.denseblock4.denselayer15.relu1, Type: ReLU
# Layer 420: Name: features.denseblock4.denselayer15.conv1, Type: Conv2d
# Layer 421: Name: features.denseblock4.denselayer15.norm2, Type: BatchNorm2d
# Layer 422: Name: features.denseblock4.denselayer15.relu2, Type: ReLU
# Layer 423: Name: features.denseblock4.denselayer15.conv2, Type: Conv2d
# Layer 424: Name: features.denseblock4.denselayer16, Type: _DenseLayer
# Layer 425: Name: features.denseblock4.denselayer16.norm1, Type: BatchNorm2d
# Layer 426: Name: features.denseblock4.denselayer16.relu1, Type: ReLU
# Layer 427: Name: features.denseblock4.denselayer16.conv1, Type: Conv2d
# Layer 428: Name: features.denseblock4.denselayer16.norm2, Type: BatchNorm2d
# Layer 429: Name: features.denseblock4.denselayer16.relu2, Type: ReLU
# Layer 430: Name: features.denseblock4.denselayer16.conv2, Type: Conv2d
# Layer 431: Name: features.norm5, Type: BatchNorm2d
# Layer 432: Name: classifier, Type: Linear
